# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('data.csv')
# Out:
# C:\Users\windows\AppData\Local\Temp\ipykernel_11716\1507164070.py:1: DtypeWarning: Columns (4,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv')

# %%
df
# Out:
#           categoryid  parentid     timestamp  visitorid event    itemid  \
# 0             1016.0     213.0           NaN        NaN   NaN       NaN
# 1              809.0     169.0           NaN        NaN   NaN       NaN
# 2              570.0       9.0           NaN        NaN   NaN       NaN
# 3             1691.0     885.0           NaN        NaN   NaN       NaN
# 4              536.0    1691.0           NaN        NaN   NaN       NaN
# ...              ...       ...           ...        ...   ...       ...
# 23033667         NaN       NaN  1.433646e+12        NaN   NaN  236931.0
# 23033668         NaN       NaN  1.440904e+12        NaN   NaN  455746.0
# 23033669         NaN       NaN  1.439694e+12        NaN   NaN  347565.0
# 23033670         NaN       NaN  1.433646e+12        NaN   NaN  287231.0
# 23033671         NaN       NaN  1.442113e+12        NaN   NaN  275768.0
#
#           transactionid property                             value
# ...

# %%
df.describe()
# Out:
#         categoryid     parentid     timestamp     visitorid        itemid  \
# count  1669.000000  1644.000000  2.303200e+07  2.756101e+06  2.303200e+07
# mean    849.285201   847.571168  1.435309e+12  7.019229e+05  2.335738e+05
# std     490.195116   505.058485  3.357729e+09  4.056875e+05  1.347686e+05
# min       0.000000     8.000000  1.430622e+12  0.000000e+00  0.000000e+00
# 25%     427.000000   381.000000  1.432436e+12  3.505660e+05  1.166760e+05
# 50%     848.000000   866.000000  1.434251e+12  7.020600e+05  2.338150e+05
# 75%    1273.000000  1291.000000  1.438035e+12  1.053437e+06  3.503800e+05
# max    1698.000000  1698.000000  1.442545e+12  1.407579e+06  4.668670e+05
#
#        transactionid
# count   22457.000000
# mean     8826.497796
# std      5098.996290
# min         0.000000
# 25%      4411.000000
# 50%      8813.000000
# 75%     13224.000000
# max     17671.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23033672 entries, 0 to 23033671
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   categoryid     float64
#  1   parentid       float64
#  2   timestamp      float64
#  3   visitorid      float64
#  4   event          object
#  5   itemid         float64
#  6   transactionid  float64
#  7   property       object
#  8   value          object
# dtypes: float64(6), object(3)
# memory usage: 1.5+ GB

# %%
df.isna().sum()
# Out:
# categoryid       23032003
# parentid         23032028
# timestamp            1669
# visitorid        20277571
# event            20277571
# itemid               1669
# transactionid    23011215
# property          2757770
# value             2757770
# dtype: int64

# %%
df['timestamp'] = pd.to_datetime(df.timestamp)

# %%
df.dtypes
# Out:
# categoryid              float64
# parentid                float64
# timestamp        datetime64[ns]
# visitorid               float64
# event                    object
# itemid                  float64
# transactionid           float64
# property                 object
# value                    object
# dtype: object

# %%
df
# Out:
#           categoryid  parentid                  timestamp  visitorid event  \
# 0             1016.0     213.0                        NaT        NaN   NaN
# 1              809.0     169.0                        NaT        NaN   NaN
# 2              570.0       9.0                        NaT        NaN   NaN
# 3             1691.0     885.0                        NaT        NaN   NaN
# 4              536.0    1691.0                        NaT        NaN   NaN
# ...              ...       ...                        ...        ...   ...
# 23033667         NaN       NaN 1970-01-01 00:23:53.646000        NaN   NaN
# 23033668         NaN       NaN 1970-01-01 00:24:00.903600        NaN   NaN
# 23033669         NaN       NaN 1970-01-01 00:23:59.694000        NaN   NaN
# 23033670         NaN       NaN 1970-01-01 00:23:53.646000        NaN   NaN
# 23033671         NaN       NaN 1970-01-01 00:24:02.113200        NaN   NaN
#
# ...

# %%
df.event.unique()
# Out:
# array([nan, 'view', 'addtocart', 'transaction'], dtype=object)

# %%
df.event.value_counts()
# Out:
# event
# view           2664312
# addtocart        69332
# transaction      22457
# Name: count, dtype: int64

# %%
new_df = df.dropna(subset = ['event'])

# %%
new_df.event.sort_values()
# Out:
# 1529015    addtocart
# 1078064    addtocart
# 881434     addtocart
# 102244     addtocart
# 1225366    addtocart
#              ...
# 936002          view
# 936003          view
# 936004          view
# 936006          view
# 2757769         view
# Name: event, Length: 2756101, dtype: object

# %%
new_df
# Out:
#          categoryid  parentid                     timestamp  visitorid event  \
# 1669            NaN       NaN 1970-01-01 00:23:53.221332117   257597.0  view
# 1670            NaN       NaN 1970-01-01 00:23:53.224214164   992329.0  view
# 1671            NaN       NaN 1970-01-01 00:23:53.221999827   111016.0  view
# 1672            NaN       NaN 1970-01-01 00:23:53.221955914   483717.0  view
# 1673            NaN       NaN 1970-01-01 00:23:53.221337106   951259.0  view
# ...             ...       ...                           ...        ...   ...
# 2757765         NaN       NaN 1970-01-01 00:23:58.398785939   591435.0  view
# 2757766         NaN       NaN 1970-01-01 00:23:58.399813142   762376.0  view
# 2757767         NaN       NaN 1970-01-01 00:23:58.397820527  1251746.0  view
# 2757768         NaN       NaN 1970-01-01 00:23:58.398530703  1184451.0  view
# 2757769         NaN       NaN 1970-01-01 00:23:58.400163914   199536.0  view
#
# ...

# %%
new_df.isna().sum()
# Out:
# categoryid       2756101
# parentid         2756101
# timestamp              0
# visitorid              0
# event                  0
# itemid                 0
# transactionid    2733644
# property         2756101
# value            2756101
# dtype: int64

# %%
labels = LabelEncoder()

# %%
new_df['event'] = labels.fit_transform(new_df.event)
# Out:
# C:\Users\windows\AppData\Local\Temp\ipykernel_11716\1836609346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['event'] = labels.fit_transform(new_df.event)

# %%
new_df
# Out:
#          categoryid  parentid                     timestamp  visitorid  event  \
# 1669            NaN       NaN 1970-01-01 00:23:53.221332117   257597.0      2
# 1670            NaN       NaN 1970-01-01 00:23:53.224214164   992329.0      2
# 1671            NaN       NaN 1970-01-01 00:23:53.221999827   111016.0      2
# 1672            NaN       NaN 1970-01-01 00:23:53.221955914   483717.0      2
# 1673            NaN       NaN 1970-01-01 00:23:53.221337106   951259.0      2
# ...             ...       ...                           ...        ...    ...
# 2757765         NaN       NaN 1970-01-01 00:23:58.398785939   591435.0      2
# 2757766         NaN       NaN 1970-01-01 00:23:58.399813142   762376.0      2
# 2757767         NaN       NaN 1970-01-01 00:23:58.397820527  1251746.0      2
# 2757768         NaN       NaN 1970-01-01 00:23:58.398530703  1184451.0      2
# 2757769         NaN       NaN 1970-01-01 00:23:58.400163914   199536.0      2
#
# ...

# %%
new_df.event.unique()
# Out:
# array([2, 0, 1])

# %%
new_df.event.replace([0,1,2],[1,3,5],inplace = True)
# Out:
# C:\Users\windows\AppData\Local\Temp\ipykernel_11716\886496120.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_df.event.replace([0,1,2],[1,3,5],inplace = True)
# C:\Users\windows\AppData\Local\Temp\ipykernel_11716\886496120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
new_df
# Out:
#          categoryid  parentid                     timestamp  visitorid  event  \
# 1669            NaN       NaN 1970-01-01 00:23:53.221332117   257597.0      5
# 1670            NaN       NaN 1970-01-01 00:23:53.224214164   992329.0      5
# 1671            NaN       NaN 1970-01-01 00:23:53.221999827   111016.0      5
# 1672            NaN       NaN 1970-01-01 00:23:53.221955914   483717.0      5
# 1673            NaN       NaN 1970-01-01 00:23:53.221337106   951259.0      5
# ...             ...       ...                           ...        ...    ...
# 2757765         NaN       NaN 1970-01-01 00:23:58.398785939   591435.0      5
# 2757766         NaN       NaN 1970-01-01 00:23:58.399813142   762376.0      5
# 2757767         NaN       NaN 1970-01-01 00:23:58.397820527  1251746.0      5
# 2757768         NaN       NaN 1970-01-01 00:23:58.398530703  1184451.0      5
# 2757769         NaN       NaN 1970-01-01 00:23:58.400163914   199536.0      5
#
# ...

# %%
new_df.event.unique()
# Out:
# array([5, 1, 3])

# %%
new_df.dtypes
# Out:
# categoryid              float64
# parentid                float64
# timestamp        datetime64[ns]
# visitorid               float64
# event                     int32
# itemid                  float64
# transactionid           float64
# property                 object
# value                    object
# dtype: object

# %%
# !pip install scikit-surprise

# %%
from surprise import Dataset
from surprise import Reader
from surprise import SVD
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
print(dir(Dataset))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'construct_testset', 'construct_trainset', 'load_builtin', 'load_from_df', 'load_from_file', 'load_from_folds', 'read_ratings']

# %%
reader = Reader()

# %%
surprise_data = Dataset.load_from_df(new_df[['visitorid','itemid','event']] , reader)

# %%
model = SVD()

# %%
surprise_data

# %%
train_X,test_X = train_test_split(surprise_data, test_size = 0.2, random_state = 42)

# %%
model.fit(train_X)

# %%
pred = model.test(test_X)

# %%
print(accuracy.rmse(pred))
# Out:
# RMSE: 0.6234
# 0.6233800056441287

# %%
def recommend_cf(user_id, n=5):
    unique_items = new_df['itemid'].unique()
    recommendations = []

    for item in unique_items:
        prediction = model.predict(user_id, item)
        recommendations.append((item, prediction.est))
    recommendations.sort(key=lambda x: x[1], reverse=True)
    return [item for item, _ in recommendations[:]]

# %%
user_id = 3 # Example user ID
top_recommendations = recommend_cf(user_id,n = 3)
print(f"Top recommendations for User {user_id}: {top_recommendations}")
# Out:
# Top recommendations for User 3: [355908.0, 318965.0, 253185.0, 439202.0, 428805.0, 82389.0, 156489.0, 402625.0, 176721.0, 132316.0, 21989.0, 250696.0, 205392.0, 123990.0, 128394.0, 45337.0, 43485.0, 280893.0, 306886.0, 159780.0, 75994.0, 367500.0, 102061.0, 134264.0, 335975.0, 55555.0, 350819.0, 323147.0, 448136.0, 140848.0, 357579.0, 395002.0, 181142.0, 302509.0, 97879.0, 255833.0, 69533.0, 261865.0, 102131.0, 458588.0, 346655.0, 279976.0, 25427.0, 347194.0, 46097.0, 459752.0, 28540.0, 13091.0, 20889.0, 7438.0, 98498.0, 37945.0, 46130.0, 310791.0, 422425.0, 10620.0, 134458.0, 261320.0, 25071.0, 256368.0, 234255.0, 268266.0, 40596.0, 429607.0, 331725.0, 71957.0, 201940.0, 72611.0, 33638.0, 86238.0, 282803.0, 138439.0, 178496.0, 170751.0, 14671.0, 402110.0, 207825.0, 336855.0, 204785.0, 164109.0, 106279.0, 153935.0, 466472.0, 32971.0, 216095.0, 308985.0, 222613.0, 203877.0, 96924.0, 84160.0, 63184.0, 189563.0, 58869.0, 19003.0, 358130.0, 63312.0, 433059.0, 159835.0, 181673.0, 197980.0
# ...
